# %% [markdown]
# # Expérience n°2

# %% [markdown]
# ## Boîte, efficacité sans contact

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Essais pour 3 cellules en parallèles

# %%
Th3 = 20

# %% [markdown]
# Distance du thermomètre aux cellules:
# Durée de l'experience:
# Tensions experimentées:

# %%
t = np.array([])
Temp = np.array([])

plt.plot(t,Temp,color = 'blue',label = "Tension 1")
plt.scatter(t,Temp, color ="red")
plt.xlabel("Temps (s)")
plt.ylabel("Température")
plt.title("Évolution du Delta T selon le nombre de cellules")
plt.grid()
plt.legend()
plt.show()
