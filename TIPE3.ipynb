# %% [markdown]
# # Éxperience n°5

# %% [markdown]
# ## Mesure alpha en circuit ouvert

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
DeltaT = np.array([
1.124141583,
1.13186269,
1.208242188,
1.349998299,
1.478587429,
1.57962767,
1.653870969,
1.944622719,
2.089657629,
2.289529318,
2.5044436,
2.648697331,
2.834009148,
2.990277764,
3.076247856,
3.202304937,
3.418108089,
3.486244782,
3.53141823,
3.705994415,
3.838493828,
3.927918625,
4.022864356,
4.208482935,
4.350323247,
4.401646609,
4.489457411,
4.664625472,
4.785108463,
4.809996578,
4.71403264,
4.901977111,
5.07493725,
5.21581425,
5.282906852,
5.333002444,
5.459296662,
5.638945256,
5.698875261,
5.747009202,
5.89974805,
6.03126681,
6.083872922,
6.122093735,
6.097291057,
6.072635737,
6.113902269,
6.171985758,
6.285052305,
6.399032296,
6.511174986,
6.559904612,
6.628757568,
6.734830201,
6.868674074,
6.907410037,
6.916662836,
6.958687498,
7.075382018,
7.190770986,
7.26766326,
7.325451344,
7.401296516,
7.493087289,
7.611463639,
7.687337101,
7.722744584,
7.785800574,
7.879334049,
8.001384999,
8.062032996,
8.103802756,
8.140267048,
8.207650726,
8.291848548,
8.366677253,
8.392788955,
8.396394848,
8.340656346,
8.429221522,
8.504193343,
8.602418932,
8.663410905,
8.741505069,
8.786518547,
8.796698139,
8.878820192,
8.95426365,
9.017970681,
9.06243607,
9.119588254,
9.188793265,
9.267208903,
9.33532789,
9.37483537,
9.408661353,
9.465252549,
9.570225655,
9.646963241,
9.697053633,
9.724001393,
9.776901217,
9.811871431,
9.871013117,
9.944635503,
10.02050129,
10.05906418,
10.1327943,
10.1713639,
10.1958734,
10.25858781,
10.30321174,
10.37023015,
10.43040303,
10.44746468,
10.47261969,
10.50324584,
10.50407924,
10.57918107,
10.64627793,
10.71567318,
10.74572388,
10.7805091,
10.82256802,
10.83905841,
10.8892254,
10.95676865,
11.04462242,
11.06516148])

Tension = np.array([0.01778200685,
0.01812072254,
0.02027266319,
0.02597255428,
0.03201112176,
0.03750589773,
0.04439691501,
0.05175011961,
0.05735664227,
0.0634090171,
0.06915529125,
0.0753769544,
0.08121337762,
0.08711581585,
0.09268817829,
0.09772922594,
0.1033260725,
0.1087260941,
0.1138631938,
0.1188865357,
0.1246309901,
0.1304348257,
0.1354858481,
0.1402241227,
0.1449647491,
0.1494046927,
0.1541063959,
0.1579326607,
0.1625026042,
0.1651148338,
0.1645646674,
0.1703717871,
0.1744165953,
0.1777772834,
0.1822985063,
0.1865854904,
0.191236847,
0.1956661664,
0.2003051037,
0.2044885454,
0.2099669366,
0.2134671569,
0.2154233301,
0.2156359023,
0.2161369527,
0.2153750757,
0.2155236489,
0.2208260222,
0.2253352272,
0.2290563854,
0.2320803422,
0.2357024061,
0.2403927999,
0.2443669363,
0.2476668288,
0.2505941415,
0.2540742389,
0.256305756,
0.2603843543,
0.2641663109,
0.2668604085,
0.2702426421,
0.2740229817,
0.27573879,
0.2800479911,
0.283499171,
0.2861939058,
0.2899618611,
0.2936610701,
0.2958654918,
0.299990321,
0.3032584087,
0.3051494015,
0.3092834783,
0.3109675852,
0.3147029391,
0.3157973736,
0.3183023228,
0.3179272209,
0.3204978065,
0.3245264559,
0.3266699863,
0.3298553985,
0.3332991068,
0.3349716825,
0.3385216454,
0.3400120592,
0.3435291895,
0.3448588902,
0.3480940666,
0.3498038079,
0.3529099789,
0.354724364,
0.3578303528,
0.3600260117,
0.3638184146,
0.3670439466,
0.3695887961,
0.3718565518,
0.3744071172,
0.3761639092,
0.3794880186,
0.3813630057,
0.3843551711,
0.3856326776,0.3891252968,0.3901378964,0.3940297069,0.394882996,0.3985704133,0.3998458553,0.4026854291,0.4045165111,0.4066892155,0.4091317812,0.410298872,0.413575436,0.4145095992,0.4173074817,0.4193792475,0.4208046917,0.4234665201,0.424412021,0.4267517731,0.4289265245,0.4298153918,0.4326429136,0.4342814058,0.4345967687])

A, B = np.polyfit(DeltaT, Tension, 1)
plt.plot(DeltaT, A*DeltaT + B, color='#4dc6ec', label = 'polyfit')
plt.scatter(DeltaT,Tension, color='#764dec', label = 'expérience', marker = '+', s = 80)
plt.xlabel('ΔT (K)')
plt.ylabel('Tension (V)')
plt.title('Détermination du coefficient Sab')
plt.text(7,0.15, 'Sab = ' + str(int(A*10000)/10000)+" V/K",fontsize = 12)
plt.legend()
plt.grid()
plt.show()
