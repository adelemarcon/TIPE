# %% [markdown]
# # Expérience n°3

# %% [markdown]
# ## Évolution du DeltaT pour 3 cellules en série

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Pas trop utile sauf si on compare avec un autre nombre de cellules en série
# faire au moins de même avec 4 cellules pour la boîte noire

# %% [markdown]
# PRINCIPE
# Mesure de la différence de température au cours du temps entre deux faces de 3 cellules branchées en série et montées en dérivation
# Utilisation d'un radiateur sur la face chaude comme support & moyen de dissiper un peu la chaleur (clairement inefficace)
# Cela montre une faiblesse des cellules Peltier
#
# DOCUMENTATION probleme réglé avec des modules entiers plus complexes ? possibilité de tests sur ces modules ??

# %%
t = np.array([0,2,4,5,7,9,10,12,14,15,17,18,20,22,23,25,27,28,30,32,34,37,40,43,45,46,48,50,51,57,63,65,66,68,70,71,73,74,76,78,86,88,90,91,94,96,98,99,105,106,111,118,120,123,126,128,129,131,138,141,142,144,146,147,149,151,152,154,156,159,161,164,166,167,169,171,174,176,177,186,187,191,197,199,200,202,204,209,212,214,217,219])
DeltaT = np.array([1.4,1.5,3.3,6,7.6,9.6,9.7,9.9,10,10.2,12.1,14.1,14.3,16.8,19,19.2,20.7,20.8,20.9,22.6,22.7,24.2,24.1,25.4,25.3,24,24.2,25.7,25.6,27,28.7,28.8,28.5,29.9,29.8,29.6,29.5,28.2,28.3,29.7,29.6,31.3,31.2,29.7,29.8,29.9,30,31.4,31.3,31.2,33.1,33.2,34.8,34.9,35,35.1,36.6,36.4,37.8,37.6,37.5,37.3,37.1,37,35.6,35.7,37.4,37.5,37.6,39.1,39,38.9,38.7,40.1,39.9,39.7,41.4,41.3,41.2,41.3,41.4,43.1,45.1,45,44.9,44.8,44.9,46.2,45.9,46,47.6,47.5])

plt.plot(t,DeltaT,color = 'blue',label = "3 cellules")
plt.scatter(t,DeltaT, color ="purple")
plt.xlabel("Temps (s)")
plt.ylabel("Delta T")
plt.title("Évolution du Delta T en fonction du temps")
plt.legend()
plt.grid()
plt.show()
