# %% [markdown]
# # Expérience n°1

# %% [markdown]
# ## Phénomène de dérive

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Température ambiante: 22°C
# Premiere mesure pour I = 1 A et U = 3,0 - 3,1 - 3,2 - 3,3
# Deuxième mesure pour I = 2 A et U = 6.8
# Troisieme mesure pour I = 0,95 U = évoluant

# %%
t1 = np.array([0,3.16,4.7,6.46,8.1,11.6,13.21,18.1,19.70,21.5,23.15,24.65,29.65,31.2,32.9,34.6,36.5,38.2,39.6,41,43,51.6,53,54.6,56,58,59.5,62,65,70,87.8,90,91,94,100,106,116,123,134,138,141,145,150,155,165,167,170,180,187,190,199,202,208,214,218,222,230,234,240,247,250,254,262,269,279,280,285,287,290,308,317])
t2 = np.array([0,5,6.6,8.7,10.2,12,13.7,15.1,16.8,18.48,20.2,21.8,23.6,25.2,26.7,36.9,40.1,43.4,46.7,51,52,54.3,55,57,64,65,66,68,70,73,81,84,85,90,92,94,99,103,110,113,114,118,120,121,123,126,130,134,136,138,139,148,149,152,158,161,163,167,171,177,181,189,191,193,196,199,202,204,205,209,211,212,214,217,220,231,235,236,239,240,242,244,245,247,251,252,255,259,261,262,264,265,269,270,271,274,275,276,278,280,282,284,285,287])
Temp1 = np.array([21,20.8,17.7,15,13.1,12.9,10.2,10.1,9.9,9.8,9.6,8,7.9,7.8,7.7,7.6,7.4,7.5,7.6,7.7,7.8,7.7,7.6,7.5,7.4,7.3,7.2,7.1,7.0,6.9,8.5,8.4,8.3,8.2,8,7.8,8,8.2,8.4,10,9.8,9.5,9.3,9.1,9.3,9.5,9.7,9.5,9.7,9.9,10.1,10.3,10.5,10.7,10.9,11.1,10.9,10.7,10.5,10.7,11,11.3,11.5,11.3,11.5,11.7,11.9,12.1,12.3,12.1,12])
Temp2 = np.array([22.2,22,15.7,12,9.2,7,5.2,5.1,3,2.9,2.8,2.6,2.5,2.3,0.8,0.9,1,1.1,1.3,1.4,1.5,1.7,1.8,3.2,3.3,3.4,3.5,3.6,3.7,3.8,3.9,5.5,5.4,5.5,5.7,7.2,7.1,7,7.1,7.3,7.5,7.7,9.2,9.4,9.5,9.6,11.2,11,10.9,10.8,10.9,11,12.6,12.5,12.4,12.3,12.4,14,13.9,13.8,14,13.9,14,14.1,14.3,14.4,15.9,16,16.1,16.2,16.3,16.4,16.5,16.6,16.7,16.8,16.9,17,18.4,18.5,18.6,18.8,18.9,19,19.1,19.2,19.3,19.4,19.5,19.6,19.7,19.8,19.9,20,20.1,20.2,20.3,20.4,22,22.1,22.3,22.4,23.9,23.8])

plt.plot(t1,Temp1,color = 'red',label = "P = 3 W")
plt.plot(t2,Temp2,color = 'blue',label = "P = 14 W")
plt.scatter(t1,Temp1, color ="pink")
plt.scatter(t2,Temp2, color ="purple")
plt.xlabel("Temps (s)")
plt.ylabel("Température")
plt.title("Évolution de la température au cours du temps")
plt.grid()
plt.legend()
plt.show()
