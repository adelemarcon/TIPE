# %% [markdown]
# # Expérience n°1

# %% [markdown]
# ## Phénomène de dérive

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Température ambiante: 22°C
# Premiere mesure pour I = 1 A et U = 3,0 - 3,1 - 3,2 - 3,3
# Deuxième mesure pour I = 2 A et U = 6.8
# Troisieme mesure pour I = 0,95 U = évoluant

# %%
t1 = np.array([0,3.16,4.7,6.46,8.1,10.21,
               24.6,43,51.6,
               65,90,100,106,116,123,134,
               155,165,180,190,199,
               208,218,234,250,262,269,280,290,308,317])
t2 = np.array([0,5,6.6,8.7,10.2,12,13.7,16.8,26.7,36.9,46.7,58.3,64,70,84,95,104,120,136,158,177,181,202,214,228,239,252,262,270,280,284])
Temp1 = np.array([21,20.8,17.7,15,13.1,10.2,
                  8,7.8,7.7,
                  8.5,8.4,8,7.8,8,8.2,8.4,
                  9.1,9.3,9.5,9.9,10.1,
                  10.5,10.9,10.7,11,11.5,11.5,12.1,12.3,12.1,12])
Temp2 = np.array([22.2,22,15.7,12,9.2,7,5.2,3,0.8,0.9,1.3,1.7,3.3,3.7,5.5,7.1,7.5,9.2,10.9,12.4,13.8,14,15.9,16.5,17,18.4,19.2,19.6,20.2,22.1,22.4])

plt.plot(t1,Temp1,color = '#3491fe',label = "P = 3 W", marker = '+')
plt.plot(t2,Temp2,color = '#fe3459',label = "P = 14 W", marker = '+')
plt.xlabel("Temps (s)")
plt.ylabel("T (°C)")
plt.title("Mise en évidence de la nécessité d'un refroidissement performant de la cellule")
plt.grid()
plt.legend()
plt.show()
