# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Generate random continuous data
data = np.random.normal(loc=50, scale=15, size=100)  # Mean=50, Std=15, 100 samples

# Create a boxplot
sns.boxplot(y=data)
plt.show()
